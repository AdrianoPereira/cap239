# %%
from pmodel import *

# %%
s = pmodel(16384, 0.62, -0.45)
tmp = ''
for x in s:
    tmp += str(x)+'\n'
tmp
# Out:
# '0.38375718\n1.78596666\n2.91587836\n0.88209098\n1.06178917\n1.8010702\n3.55352183\n1.53846105\n7.15667772\n4.34404137\n1.12068301\n4.2171765\n0.95283124\n2.13050626\n2.42855882\n4.31041501\n0.41521971\n3.54573236\n0.61079068\n0.35580272\n1.35425995\n0.8173116\n0.75711281\n-0.32171189\n2.51365444\n0.93129785\n0.28113496\n0.8638977\n5.66641532\n2.0972771\n2.81271961\n0.83280135\n0.21800324\n-0.36763198\n1.03773968\n1.22883431\n1.26759086\n3.09067078\n0.1357763\n0.4480673\n-0.16182399\n0.64602494\n0.20477444\n1.01568962\n-0.32737186\n-0.24440682\n0.65695883\n1.53505698\n0.01706868\n-0.28798123\n1.04204886\n0.43408099\n3.18248263\n0.06445972\n1.13708512\n0.49361184\n1.35623453\n0.18101029\n1.1699452\n2.37520512\n2.9527712\n0.13431902\n4.86208998\n2.06261851\n-1.11037251\n-0.46723054\n-0.22714481\n-0.00728658\n-0.53733278\n0.19124723\n-0.10940488\n-0.95846644\n1.21235859\n0.64411037\n0.89634233\n0.16099434\n0.13778515\n1.04330341\n0.35801925\n0.01911658\n-0.30690754\n0.69649309\n0.663185
# ...

# %%
with open('s22.txt', 'a') as f:
    f.write(tmp)

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '3DBMO_PSD_DFA_2.png',
#  'cappy239',
#  'custom.css',
#  'homework_spectral_analysis.ipynb',
#  'homework_spectral_analysis.pdf',
#  'Pmodel.ipynb',
#  'pmodel.py',
#  'psd_dfa.py',
#  'scripts',
#  'serie1.txt',
#  'teste',
#  'teste.cpp',
#  'th.csv',
#  'txt.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  '__pycache__']
