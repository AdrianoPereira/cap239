# %%
from pmodel import *

# %%
s = pmodel(4096, 0.52, -1.66)
tmp = ''
for x in s:
    tmp += str(x)+'\n'
tmp
# Out:
# '0.88251736\n0.86946433\n0.88970064\n0.87891776\n0.87328698\n0.87561436\n0.88810955\n0.91306644\n0.92422162\n0.9247995\n0.95978447\n0.95143387\n0.93515268\n0.91521371\n0.90424015\n0.90050605\n0.894123\n0.90745233\n0.88869504\n0.86505259\n0.86355636\n0.85371171\n0.87158958\n0.86903332\n0.8952183\n0.89750067\n0.89629616\n0.88794678\n0.86569962\n0.86639274\n0.8756105\n0.89594263\n0.89400421\n0.90916184\n0.87935212\n0.88688816\n0.86779502\n0.86769968\n0.87242513\n0.88064043\n0.92148362\n0.92089062\n0.92029758\n0.91766366\n0.94667523\n0.95760868\n0.93201412\n0.93797024\n0.92678849\n0.92652238\n0.92817234\n0.94541585\n0.92616823\n0.90625243\n0.89666534\n0.92016658\n0.92702843\n0.95700111\n0.96765024\n0.96864864\n0.9990622\n0.99723972\n0.96332393\n0.96663474\n0.92120377\n0.9245166\n0.93174204\n0.93524951\n0.88916932\n0.88806366\n0.89746286\n0.88238136\n0.88602608\n0.8935627\n0.90429575\n0.89647923\n0.89764081\n0.91029242\n0.90684748\n0.93428484\n0.9319648\n0.94457567\n0.95039874\n0.95261528
# ...

# %%
with open('s8.txt', 'a') as f:
    f.write(tmp)

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '3DBMO_PSD_DFA_2.png',
#  'cappy239',
#  'custom.css',
#  'homework_spectral_analysis.ipynb',
#  'homework_spectral_analysis.pdf',
#  'Pmodel.ipynb',
#  'pmodel.py',
#  'psd_dfa.py',
#  'scripts',
#  'serie1.txt',
#  'teste',
#  'teste.cpp',
#  'th.csv',
#  'txt.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  '__pycache__']
