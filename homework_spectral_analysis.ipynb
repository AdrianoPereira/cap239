# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
from scripts.functions import powernoise, logistic_map
# import pmodel 
import seaborn as sns
import math
from scipy import stats
# from sklearn.preprocessing import MinMaxScaler
# Out:
# c:\users\samsung\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
white_noise_normalize = powernoise(beta=0, N=2**12, varargin='normalize')
white_noise_ranpower = powernoise(beta=0, N=2**12, varargin='ranpower')

pink_noise_normalize = powernoise(beta=1, N=2**12, varargin='normalize')
pink_noise_ranpower = powernoise(beta=1, N=2**12, varargin='ranpower')

red_noise_normalize = powernoise(beta=2, N=2**12, varargin='normalize')
red_noise_ranpower = powernoise(beta=2, N=2**12, varargin='ranpower')

s1 = white_noise_normalize
s2 = pink_noise_normalize
s3 = red_noise_normalize

# %%
plt.figure(figsize=(17, 10))
plt.title('White Noise β=0', fontdict={'fontsize': '35'}, y=1.03)
plt.xlabel('N', fontdict={'fontsize': '25'})
plt.plot(white_noise_normalize, color='#d6d6d6')

# %%
plt.figure(figsize=(17, 10))
plt.title('Pink Noise β=1', fontdict={'fontsize': '35'}, y=1.03)
plt.xlabel('N', fontdict={'fontsize': '25'})
plt.plot(pink_noise_normalize, color='hotpink')

# %%
plt.figure(figsize=(17, 10))
plt.title('Red Noise β=2', fontdict={'fontsize': '35'}, y=1.03)
plt.xlabel('N', fontdict={'fontsize': '25'})
plt.plot(red_noise_normalize, color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-496ea2a67669> in <module>()
# ----> 1 plt.figure(figsize=(17, 10))
#       2 plt.title('Red Noise β=2', fontdict={'fontsize': '35'}, y=1.03)
#       3 plt.xlabel('N', fontdict={'fontsize': '25'})
#       4 plt.plot(red_noise_normalize, color='red')
#
# NameError: name 'plt' is not defined

# %%
s4 = logistic_map(rho=4, a0=0.001, n=2**12)
plt.figure(figsize=(17, 10))
plt.title('Logistic Map ρ=4', fontdict={'fontsize': '35'}, y=1.03)
plt.xlabel('N', fontdict={'fontsize': '25'})
plt.plot(s4, color='#0000FF')

# %%
fig, ax = plt.subplots(figsize=(17, 10))
ax.plot(logistic_map(rho=1, a0=0.001, n=100), label='rho=1', color='red')
ax.plot(logistic_map(rho=2, a0=0.001, n=100), label='rho=2', color='blue')
ax.plot(logistic_map(rho=3, a0=0.001, n=100), label='rho=3', color='black')
ax.plot(logistic_map(rho=4, a0=0.001, n=100), label='rho=4', color='green')
fig.legend()

# %%
def normalize(x):
    return ((x - min(x)) / (max(x) - min(x)) - 0.5) * 2

# %%
s5 = normalize(s1+s4)
s6 = normalize(s2+s4)
s7 = normalize(s3+s4)
